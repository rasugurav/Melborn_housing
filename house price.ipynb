# %% [markdown]
# <a href="https://colab.research.google.com/github/rasugurav/Melborn_housing/blob/master/house%20price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sns
import tensorflow as tf

# %%
df_train=pd.read_csv('/content/train.csv')

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df_test=pd.read_csv('/content/test.csv')

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
total=df_train.isnull().sum()[df_train.isnull().sum()>0].sort_values(ascending=False)

# %%
total
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
percentage=(df_train.isnull().sum()/df_train.isnull().count())[df_train.isnull().sum()/df_train.isnull().count()>0].sort_values(ascending=False)

# %%
percentage
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageYrBlt     0.055479
# GarageType      0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# BsmtFinType2    0.026027
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtCond        0.025342
# BsmtQual        0.025342
# MasVnrArea      0.005479
# MasVnrType      0.005479
# Electrical      0.000685
# dtype: float64

# %%
feature_with_missing=[feature for feature in df_train.columns if df_train[feature].isnull().sum()>0]
for feature in feature_with_missing:
  print(feature,np.round(df_train[feature].isnull().mean(),4))
# Out:
# LotFrontage 0.1774
# Alley 0.9377
# MasVnrType 0.0055
# MasVnrArea 0.0055
# BsmtQual 0.0253
# BsmtCond 0.0253
# BsmtExposure 0.026
# BsmtFinType1 0.0253
# BsmtFinType2 0.026
# Electrical 0.0007
# FireplaceQu 0.4726
# GarageType 0.0555
# GarageYrBlt 0.0555
# GarageFinish 0.0555
# GarageQual 0.0555
# GarageCond 0.0555
# PoolQC 0.9952
# Fence 0.8075
# MiscFeature 0.963

# %%
for feature in feature_with_missing:
  df=df_train.copy()
  df[feature]=np.where(df[feature].isnull(),1,0)
  plt.figure(figsize=(10,5))
  df.groupby(feature)['SalePrice'].mean().plot.bar()
  plt.ylabel(' Sale Price')
  plt.legend(['1 for missing value'])
  plt.show()

# %%
numerical_feature=[feature for feature in df_train.columns if df[feature].dtype!='O']

# %%
df_train[numerical_feature].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008     208500
# 1   2          20         80.0     9600  ...        0       5    2007     181500
# 2   3          60         68.0    11250  ...        0       9    2008     223500
# 3   4          70         60.0     9550  ...        0       2    2006     140000
# 4   5          60         84.0    14260  ...        0      12    2008     250000
#
# [5 rows x 39 columns]

# %%
categorical_feature=[feature for feature in df_train.columns if df_train[feature].dtype=='O']

# %%
df_train[categorical_feature].head()
# Out:
#   MSZoning Street Alley LotShape  ... Fence MiscFeature SaleType SaleCondition
# 0       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 1       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 2       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
# 3       RL   Pave   NaN      IR1  ...   NaN         NaN       WD       Abnorml
# 4       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
year_feature=[feature for feature in df[numerical_feature] if 'Yr' in feature or 'yr' in feature or 'Year' in feature or 'Year' in feature]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
df_train[year_feature].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0       2003          2003       2003.0    2008
# 1       1976          1976       1976.0    2007
# 2       2001          2002       2001.0    2008
# 3       1915          1970       1998.0    2006
# 4       2000          2000       2000.0    2008

# %%
for feature in year_feature:
  df_train.groupby(feature)['SalePrice'].median().plot()
  plt.ylabel('Meadian Price')
  plt.xlabel(feature)
  plt.show()

# %%
discrete_variable=[feature for feature in numerical_feature if len(df_train[feature].unique())<25 and feature not in year_feature+['Id']]

# %%
df_train[discrete_variable].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  ...  MiscFeature  MiscVal  MoSold
# 0          60            7            5  ...          NaN        0       2
# 1          20            6            8  ...          NaN        0       5
# 2          60            7            5  ...          NaN        0       9
# 3          70            7            5  ...          NaN        0       2
# 4          60            8            5  ...          NaN        0      12
#
# [5 rows x 18 columns]

# %%
for feature in discrete_variable:
  df_train.groupby(feature)['SalePrice'].median().plot.bar()
  plt.ylabel('Sale Price')
  plt.xlabel(feature)
  plt.show()

# %%
continuos_variable=[feature for feature in numerical_feature if feature not in discrete_variable+['Id'] and feature not in year_feature+['SalePrice']]

# %%
df_train[continuos_variable].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  ...  OpenPorchSF  EnclosedPorch  ScreenPorch
# 0         65.0     8450       196.0  ...           61              0            0
# 1         80.0     9600         0.0  ...            0              0            0
# 2         68.0    11250       162.0  ...           42              0            0
# 3         60.0     9550         0.0  ...           35            272            0
# 4         84.0    14260       350.0  ...           84              0            0
#
# [5 rows x 15 columns]

# %%
for feature in continuos_variable:
  plt.scatter(x=df_train[feature],y=df_train['SalePrice'])
  plt.ylabel('Sale Price')
  plt.xlabel(feature)
  plt.show()

# %%
for feature in categorical_feature:
  df_train.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.ylabel('Sale price ')
  plt.title('Categorical variable vs Sale price')
  plt.show()

# %%
feature_nan = [feature for feature in df_train.columns if df_train[feature].isnull().sum()>1 and df_train[feature].dtypes == 'O']

def replace_cat_feature(df,feature_nan):
    data = df.copy()
    
    data[feature_nan]=data[feature_nan].fillna('Missing')
    return data
df_train = replace_cat_feature(df_train, feature_nan)
df_train[feature_nan].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-6801a6babf2c> in <module>()
# ----> 1 feature_nan = [feature for feature in df_train.columns if df_train[feature].isnull().sum()>1 and df_train[feature].dtypes == 'O']
#       2
#       3 def replace_cat_feature(df,feature_nan):
#       4     data = df.copy()
#       5
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
df_train=fill_nan(df_train,feature)
df_train[feature].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-9c25f0576e9c> in <module>()
# ----> 1 df_train=fill_nan(df_train,feature)
#       2 df_train[feature].isnull().sum()
#
# <ipython-input-70-c9b75e739cb2> in fill_nan(df, feature)
#       1 for feature in categorical_feature:
#       2   def fill_nan(df,feature):
# ----> 3     data=df_train.copy()
#       4     data[feature]=data[feature].fillna('Missing')
#       5     return data
#
# AttributeError: 'NoneType' object has no attribute 'copy'
